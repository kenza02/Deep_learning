# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git
# %cd /content/yolov5
# !pip install -r requirements.txt
# !pip install "wandb==0.12.10"

# %%
#train Yolo Model
# !yolo task=detect mode=train model=yolov5s.pt data=/content/drive/MyDrive/wind/data/wind_turbines/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 17.7M/17.7M [00:00<00:00, 190MB/s]
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# EVALUATION
# !yolo task=detect mode=val model=/content/yolov5/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/wind/data/wind_turbines/data.yaml
# Out:
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5s summary (fused): 193 layers, 9112310 parameters, 0 gradients, 23.8 GFLOPs
# val: Scanning /content/drive/MyDrive/wind/data/wind_turbines/valid/labels.cache... 247 images, 1 backgrounds, 0 corrupt: 100% 247/247 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:12<00:00,  1.33it/s]
#                    all        247       1562      0.906      0.825       0.89       0.56
#            cable tower        247         24          1      0.778      0.875       0.49
#                turbine        247       1538      0.811      0.871      0.906       0.63
# Speed: 0.9ms preprocess, 8.0ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !cp /content/yolov5/runs/detect/train/weights/best.pt /content/drive/MyDrive/wind/data/wind_turbines/best_model.pt
